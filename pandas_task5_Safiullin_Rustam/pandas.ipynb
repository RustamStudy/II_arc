# %%
import pandas as pd

# %%
dateSet= pd.read_csv('Titanic-Dataset.csv', delimiter=',')
dateSet
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dateSet.columns.values.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# # Количество пустых значений

# %%
dateSet.isnull().sum().sum ()
# Out:
# 866

# %% [markdown]
# Заполнение пустых ячеек
# ---

# %%
dateSetNew = dateSet.fillna('newValue')
dateSetNew
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male      22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      38.0
# 2                               Heikkinen, Miss. Laina  female      26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      35.0
# 4                             Allen, Mr. William Henry    male      35.0
# ..                                                 ...     ...       ...
# ...

# %%
dateSetNew.isnull().sum().sum ()
# Out:
# 0

# %% [markdown]
# # Удаление пустых ячеек

# %%
dateSetDelete= dateSet.dropna()
dateSetDelete
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dateSetDelete.isnull().sum().sum ()
# Out:
# 0

# %% [markdown]
# # Минимальные и максимальные значения

# %% [markdown]
# Возраст

# %%
maxAge = dateSet['Age'].max()
maxAge
# Out:
# 80.0

# %%
minAge = dateSet['Age'].min()
minAge
# Out:
# 0.42

# %% [markdown]
# Цена

# %%
maxFare = dateSet['Fare'].max()
maxFare
# Out:
# 512.3292

# %%
minFare = dateSet['Fare'].min()
minFare
# Out:
# 0.0

# %% [markdown]
# Братья и сестры

# %%
maxSibSp = dateSet['SibSp'].max()
maxSibSp
# Out:
# 8

# %%
minSibSp = dateSet['SibSp'].min()
minSibSp
# Out:
# 0

# %% [markdown]
# родители и дети

# %%
maxParch = dateSet['Parch'].max()
maxParch
# Out:
# 6

# %%
minParch = dateSet['Parch'].min()
minParch
# Out:
# 0

# %% [markdown]
# # Уникальные значения

# %% [markdown]
# Класс

# %%
dateSet['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
dateSet['Pclass'].nunique()
# Out:
# 3

# %% [markdown]
# каюта

# %%
dateSet['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
dateSet['Cabin'].nunique()
# Out:
# 147

# %% [markdown]
# Порт постадки

# %%
dateSet['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
dateSet['Embarked'].nunique()
# Out:
# 3
